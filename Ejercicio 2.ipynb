# %% [markdown]
# ## Ejercicio
# Escribir un programa que almacene la frase "¡Hola mundo!" en una variable y luego la muestre en pantalla.

# %%
X = "¡Hola mundo!"
print(X)
# Out:
# ¡Hola mundo!

# %% [markdown]
# ## Solución
